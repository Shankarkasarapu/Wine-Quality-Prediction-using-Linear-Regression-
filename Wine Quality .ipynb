# %%
import pandas as pd
import numpy as np

# %%
#IMPORT THE DATASET 
data=pd.read_csv('winequality-red.csv') #reading the dataset
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.shape
# Out:
# (1599, 12)

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data.isnull().sum()  #checking the null value
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.describe() #finding the statistical value of numerical columns
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
#  Data Visualisation

# %%
# we need to import seaborn library for visualising the data
import seaborn as sns
sns.catplot(x='quality',data=data,kind='count')
#below plot having quality starting from 3 to 8  on the x-axis and count on the y-axis

# %%
#quality vs volatile acidity 
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
sns.barplot(x='quality',y='volatile acidity',data=data)   #the quality of the wine is low when the volatile acidity if high
                                                          #both are negitivly correlated
# Out:
# <AxesSubplot:xlabel='quality', ylabel='volatile acidity'>

# %%
#quality vs citric acid 
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5)) 
sns.barplot(x='quality',y='citric acid',data=data) #the quality of the high is increasing when the level of citric acid is high 
#they are positively correlated
# Out:
# <AxesSubplot:xlabel='quality', ylabel='citric acid'>

# %%
a=wine_data.corr()
a
#finding the correlation between the variables
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(a,data=data,annot=True,cmap='Blues')  #its a confusion matrix/ correlation matrix
# Out:
# <AxesSubplot:>

# %%
# Split the data into training and target variables
X = wine_data.drop('quality', axis=1)  # Drop the 'quality' column from the input features
Y = wine_data['quality']  # Assign the 'quality' column as the target variable

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# Create a linear regression model
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# Fit the model to the training data
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pred=model.predict(X_test)
print(pred)
# Out:
# [5.34666441 5.05631345 5.66446972 5.46451484 5.72518476 5.27928659
#  5.03421667 5.12623347 5.74534288 5.68665032 6.13959677 5.23386892
#  5.54991474 5.25825299 5.44810502 6.46828999 5.15018088 5.59105157
#  6.5560658  5.32255751 5.3918385  5.19610791 5.94475739 6.36197631
#  5.35484893 5.41907575 6.36483321 5.35121573 5.172392   6.16987311
#  5.25263058 5.50657406 5.75422105 5.39101712 5.45331031 5.02757499
#  6.16173243 5.68661555 5.6486077  6.165471   5.52872593 5.24414488
#  6.17724727 5.16500868 5.87598332 5.81317121 6.41982782 5.6059474
#  5.15232137 5.55634632 5.16044852 5.10449459 5.58371721 6.33425313
#  4.95134985 4.98364804 6.01041999 5.40809804 5.83802638 5.2486897
#  5.60717482 5.96630957 5.27619063 5.30380113 6.4949309  5.42033967
#  6.34273471 5.24618531 6.41317317 5.31237924 6.41746963 4.74315748
#  5.79362039 5.8283184  6.17598768 5.29723707 6.76198733 5.89745261
#  6.07833712 6.43522754 5.29499011 6.4546625  5.45007864 5.69644693
# ...

# %%
model.score(X_test,y_test)
# Out:
# 0.7013421134234

# %%
input=(7.8,0.57,0.09,2.3,0.065,34.0,45.0,0.9941700000000001,3.46,0.74,12.7)
new=np.asarray(input)

# %%
inpu=new.reshape(1,-1)

# %%
pred_ac=model.predict(inpu)
pred_ac
# Out:
# C:\Users\kasar\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
if pred_ac[0]>=6:print("good quality wine!")
else : print("bad quality  wine")
# Out:
# good quality wine!
